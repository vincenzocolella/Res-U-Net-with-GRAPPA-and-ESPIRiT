# %%
tar -czvf backup.tar.gz --exclude='multicoil_values' --exclude='brain_leaderboard_state_dict.pt' *
# Out:
# Notebook.ipynb
# Notebook_with_GRAPPA.ipynb
# Notebook_with_Res-U-Net.ipynb
# Removing_Duplicates_and_more.ipynb
# __pycache__/
# __pycache__/multi_res_unet_3D.cpython-38.pyc
# __pycache__/multi_res_unet.cpython-38.pyc
# __pycache__/utils_dont_remove.cpython-38.pyc
# backup.tar.gz
# tar: backup.tar.gz: file changed as we read it
# check_new_checkpoint.ipynb
# comandi_bash.ipynb
# dataset_cache.pkl
# fastMRI/
# fastMRI/tests/
# fastMRI/tests/.ipynb_checkpoints/
# fastMRI/tests/.ipynb_checkpoints/test_modules-checkpoint.py
# fastMRI/tests/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# fastMRI/tests/test_transforms.py
# fastMRI/tests/test_data.py
# fastMRI/tests/test_math.py
# fastMRI/tests/__pycache__/
# fastMRI/tests/__pycache__/__init__.cpython-38.pyc
# fastMRI/tests/__pycache__/test_data.cpython-38-pytest-6.2.4.pyc
# fastMRI/tests/__pycache__/test_math.cpython-38-pytest-6.2.4.pyc
# fastMRI/tests/__pycache__/test_integrations.cpython-38-pytest-6.2.4.pyc
# ...

# %%
#!cp -a ../../multicoil_val/. /home/colellav/multicoil_values/multicoil_train # per copiare file da root
#!cp -au ../../multicoil_val/. /home/colellav/multicoil_values/multicoil_train #per copiare solo file mancanti

# %%
# Out:
# bash: import: command not found
# bash: import: command not found
# bash: syntax error near unexpected token `('
# bash: syntax error near unexpected token `('
# bash: slice_idx: command not found
# bash: syntax error near unexpected token `ax1,'
# bash: syntax error near unexpected token `mri1[slice_idx, :, :],'
# bash: syntax error near unexpected token `'MRI 1''
# bash: syntax error near unexpected token `mri2[slice_idx, :, :],'
# bash: syntax error near unexpected token `'MRI 2''
# bash: syntax error near unexpected token `In'
# : 2
